# %%
'welcome to copper model project'
# Out:
# 'welcome to copper model project'

# %%
import pandas as pd
import numpy as np
data_pre_model = pd.read_csv("C:\\Users\\ADMIN\\Desktop\\raraj\\Copper_Set - Copy.csv", encoding="latin-1")
data_pre_model
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_7880\2596874070.py:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_pre_model = pd.read_csv("C:\\Users\\ADMIN\\Desktop\\raraj\\Copper_Set - Copy.csv", encoding="latin-1")
#                                           id   item_date quantity tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262
# ...                                      ...         ...           ...
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76  20200702.0   102.4824216
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB  20200702.0   208.0864686
# ...

# %%
data_pre_model.columns
# Out:
# Index(['id', 'item_date', 'quantity tons', 'customer', 'country', 'status',
#        'item type', 'application', 'thickness', 'width', 'material_ref',
#        'product_ref', 'delivery date', 'selling_price'],
#       dtype='object')

# %%
filtered_df = data_pre_model[data_pre_model['status'] == 'Lost']
filtered_df
# Out:
#                                           id   item_date quantity tons  \
# 171     C0BF3187-C4B3-4C63-ABDB-FCB0642A69C0  20210401.0      8.718789
# 174     66D8E20C-AF4A-47D7-8FDD-51DEA6EA1F05  20210401.0     39.553513
# 175     4532B5EF-0446-4880-BC8E-242E89AB8DD6  20210401.0     11.454558
# 176     EE0BA8DE-38E9-4101-ADF9-B7B5B19A3525  20210401.0     37.655526
# 179     1CDD04C3-6310-431F-B10A-F1C6B4F529DD  20210401.0     10.291602
# ...                                      ...         ...           ...
# 181527  A30A09D6-6527-4BE3-B2EC-B795F94A70DD  20200702.0   63.85952061
# 181529  BD9B7299-6FD2-4A9F-B336-5F677794A03F  20200702.0   56.02856191
# 181531  BF93A919-5970-428F-9467-7A2D0573C5C6  20200702.0   206.2241104
# 181533  FA54AED7-360E-4DED-96AA-F69D127267B8  20200702.0   102.9938488
# 181535  2D65F26A-E56A-4FF4-B586-6E361980EE0A  20200702.0   106.0722618
#
#           customer  country status item type  application  thickness   width  \
# ...

# %%
data_pre_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181673 entries, 0 to 181672
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             181671 non-null  object
#  1   item_date      181672 non-null  float64
#  2   quantity tons  181673 non-null  object
#  3   customer       181672 non-null  float64
#  4   country        181645 non-null  float64
#  5   status         181671 non-null  object
#  6   item type      181673 non-null  object
#  7   application    181649 non-null  float64
#  8   thickness      181672 non-null  float64
#  9   width          181673 non-null  float64
#  10  material_ref   103754 non-null  object
#  11  product_ref    181673 non-null  int64
#  12  delivery date  181672 non-null  float64
#  13  selling_price  181672 non-null  float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 19.4+ MB

# %%
data_pre_model.isnull().sum()
# Out:
# id                   2
# item_date            1
# quantity tons        0
# customer             1
# country             28
# status               2
# item type            0
# application         24
# thickness            1
# width                0
# material_ref     77919
# product_ref          0
# delivery date        1
# selling_price        1
# dtype: int64

# %% [markdown]
# DATA PREPROCESSING

# %%
data_pre_model.drop(columns=["material_ref","id"],inplace=True)

# %%
data_pre_model.shape
# Out:
# (181673, 12)

# %%
data_pre_model.head()
# Out:
#     item_date quantity tons    customer  country status item type  \
# 0  20210401.0     54.151139  30156308.0     28.0    Won         W
# 1  20210401.0    768.024839  30202938.0     25.0    Won         W
# 2  20210401.0    386.127949  30153963.0     30.0    Won        WI
# 3  20210401.0    202.411065  30349574.0     32.0    Won         S
# 4  20210401.0    785.526262  30211560.0     28.0    Won         W
#
#    application  thickness   width  product_ref  delivery date  selling_price
# 0         10.0       2.00  1500.0   1670798778     20210701.0         854.00
# 1         41.0       0.80  1210.0   1668701718     20210401.0        1047.00
# 2         28.0       0.38   952.0       628377     20210101.0         644.33
# 3         59.0       2.30  1317.0   1668701718     20210101.0         768.00
# 4         10.0       4.00  2000.0       640665     20210301.0         577.00

# %%
#Changing data types
data_pre_model["item_date"]=pd.to_datetime(data_pre_model["item_date"],format="%Y%m%d",errors='coerce')
data_pre_model['quantity tons']=pd.to_numeric(data_pre_model['quantity tons'],errors='coerce')
data_pre_model['customer']=pd.to_numeric(data_pre_model['customer'],errors='coerce')
data_pre_model['country']=pd.to_numeric(data_pre_model['country'],errors='coerce')
data_pre_model['application']=pd.to_numeric(data_pre_model['application'],errors='coerce')
data_pre_model['thickness']=pd.to_numeric(data_pre_model['thickness'],errors='coerce')
data_pre_model['width']=pd.to_numeric(data_pre_model['width'],errors='coerce')
data_pre_model['product_ref']=pd.to_numeric(data_pre_model['product_ref'],errors='coerce')
data_pre_model['delivery date']=pd.to_datetime(data_pre_model['delivery date'],format="%Y%m%d",errors='coerce')
data_pre_model['selling_price']=pd.to_numeric(data_pre_model['selling_price'],errors='coerce')

# %%
data_pre_model['item_date'].unique()
# Out:
# <DatetimeArray>
# ['2021-04-01 00:00:00',                 'NaT', '2021-03-31 00:00:00',
#  '2021-03-30 00:00:00', '2021-03-29 00:00:00', '2021-03-28 00:00:00',
#  '2021-03-27 00:00:00', '2021-03-26 00:00:00', '2021-03-25 00:00:00',
#  '2021-03-24 00:00:00',
#  ...
#  '2020-07-12 00:00:00', '2020-07-10 00:00:00', '2020-07-09 00:00:00',
#  '2020-07-08 00:00:00', '2020-07-07 00:00:00', '2020-07-06 00:00:00',
#  '2020-07-05 00:00:00', '2020-07-04 00:00:00', '2020-07-03 00:00:00',
#  '2020-07-02 00:00:00']
# Length: 251, dtype: datetime64[ns]

# %%
data_pre_model['quantity tons'].unique()
# Out:
# array([   54.15113862,   768.0248392 ,   386.1279489 , ...,
#            4.23559357, -2000.        ,   406.6865384 ])

# %%
data_pre_model["quantity tons"]=data_pre_model["quantity tons"].apply(lambda x: np.nan if x <=0 else x)
data_pre_model["selling_price"]=data_pre_model["selling_price"].apply(lambda x: np.nan if x <=0 else x)

# %%
data_pre_model['quantity tons'].value_counts().sum()
# Out:
# 181668

# %%
data_pre_model.dropna(subset=['customer'], inplace=True)

# %%
data_pre_model['customer'].unique()
# Out:
# array([30156308., 30202938., 30153963., ..., 30349515., 30284694.,
#        30161559.])

# %%
data_pre_model['country'].unique()
# Out:
# array([ 28.,  25.,  30.,  32.,  38.,  78.,  27.,  77., 113.,  79.,  26.,
#         39.,  40.,  84.,  80., 107.,  89.,  nan])

# %%
data_pre_model['status'].unique()
# Out:
# array(['Won', 'Draft', 'To be approved', 'Lost', 'Not lost for AM',
#        'Wonderful', 'Revised', 'Offered', 'Offerable', nan], dtype=object)

# %%
data_pre_model['item type'].unique()
# Out:
# array(['W', 'WI', 'S', 'Others', 'PL', 'IPL', 'SLAWR'], dtype=object)

# %%
data_pre_model['application'].unique()
# Out:
# array([10., 41., 28., 59., 15.,  4., 38., 56., 42., 26., 27., 19., 20.,
#        66., 29., 22., 40., 25., 67., 79.,  3., 99.,  2.,  5., 39., 69.,
#        70., 65., 58., 68., nan])

# %%
data_pre_model['width'].unique()
# Out:
# array([1500., 1210.,  952., ..., 1831., 1741., 1786.])

# %%
data_pre_model['product_ref'].unique()
# Out:
# array([1670798778, 1668701718,     628377,     640665,     611993,
#        1668701376,  164141591, 1671863738, 1332077137,     640405,
#        1693867550, 1665572374, 1282007633, 1668701698,     628117,
#        1690738206,     628112,     640400, 1671876026,  164336407,
#         164337175, 1668701725, 1665572032,     611728, 1721130331,
#        1693867563,     611733, 1690738219, 1722207579,  929423819,
#        1665584320, 1665584662, 1665584642], dtype=int64)

# %%
data_pre_model['delivery date'].unique()
# Out:
# <DatetimeArray>
# ['2021-07-01 00:00:00', '2021-04-01 00:00:00', '2021-01-01 00:00:00',
#  '2021-03-01 00:00:00', '2021-06-01 00:00:00', '2021-05-01 00:00:00',
#  '2021-08-01 00:00:00',                 'NaT', '2021-09-01 00:00:00',
#  '2021-10-01 00:00:00', '2021-11-01 00:00:00', '2022-01-01 00:00:00',
#  '2020-07-01 00:00:00', '2020-10-01 00:00:00', '2020-01-01 00:00:00',
#  '2021-02-01 00:00:00', '2021-12-01 00:00:00', '2019-07-01 00:00:00',
#  '2020-08-01 00:00:00', '2020-11-01 00:00:00', '2020-12-01 00:00:00',
#  '2019-04-01 00:00:00', '2020-06-01 00:00:00', '2020-04-01 00:00:00',
#  '2020-09-01 00:00:00', '2020-05-01 00:00:00', '2019-10-01 00:00:00']
# Length: 27, dtype: datetime64[ns]

# %%
data_pre_model.isnull().sum()
# Out:
# item_date         3
# quantity tons     5
# customer          0
# country          28
# status            2
# item type         0
# application      24
# thickness         1
# width             0
# product_ref       0
# delivery date     3
# selling_price     8
# dtype: int64

# %%
print(data_pre_model.duplicated().sum())
# Out:
# 0

# %%
data_pre=data_pre_model.drop_duplicates()

# %% [markdown]
# HANDLING NULL VALUES WITH MEDIAN,MODE

# %%
#HANDLING NULL VALUES WITH MEDIAN,MODE

# %%
category_colm = ["delivery date", "status", "item_date"]
continuous_colm = ["quantity tons", "customer", "country", "application", "thickness", "selling_price"]

for colm in category_colm:
    data_pre_model[colm] = data_pre_model[colm].fillna(data_pre_model[colm].mode()[0])
    print("----------------")
    print(data_pre_model[colm].unique())

for colms in continuous_colm:
    data_pre_model[colms]=data_pre_model[colms].fillna(data_pre_model[colms].median())
    print("----------------")
    print(data_pre_model[colms].unique())
# Out:
# ----------------
# <DatetimeArray>
# ['2021-07-01 00:00:00', '2021-04-01 00:00:00', '2021-01-01 00:00:00',
#  '2021-03-01 00:00:00', '2021-06-01 00:00:00', '2021-05-01 00:00:00',
#  '2021-08-01 00:00:00', '2021-09-01 00:00:00', '2021-10-01 00:00:00',
#  '2021-11-01 00:00:00', '2022-01-01 00:00:00', '2020-07-01 00:00:00',
#  '2020-10-01 00:00:00', '2020-01-01 00:00:00', '2021-02-01 00:00:00',
#  '2021-12-01 00:00:00', '2019-07-01 00:00:00', '2020-08-01 00:00:00',
#  '2020-11-01 00:00:00', '2020-12-01 00:00:00', '2019-04-01 00:00:00',
#  '2020-06-01 00:00:00', '2020-04-01 00:00:00', '2020-09-01 00:00:00',
#  '2020-05-01 00:00:00', '2019-10-01 00:00:00']
# Length: 26, dtype: datetime64[ns]
# ----------------
# ['Won' 'Draft' 'To be approved' 'Lost' 'Not lost for AM' 'Wonderful'
#  'Revised' 'Offered' 'Offerable']
# ----------------
# <DatetimeArray>
# ['2021-04-01 00:00:00', '2020-12-02 00:00:00', '2021-03-31 00:00:00',
# ...

# %%
data_pre_model[data_pre_model['selling_price'] <= 0]
# Out:
# Empty DataFrame
# Columns: [item_date, quantity tons, customer, country, status, item type, application, thickness, width, product_ref, delivery date, selling_price]
# Index: []

# %%
data_pre_model.nunique()
# Out:
# item_date           250
# quantity tons    181667
# customer           1169
# country              17
# status                9
# item type             7
# application          30
# thickness           594
# width              1386
# product_ref          33
# delivery date        26
# selling_price      9789
# dtype: int64

# %% [markdown]
# FINAL CHECKING NULL VALUES

# %%
#Final checking null values

# %%
data_pre_model.isnull().sum()
# Out:
# item_date        0
# quantity tons    0
# customer         0
# country          0
# status           0
# item type        0
# application      0
# thickness        0
# width            0
# product_ref      0
# delivery date    0
# selling_price    0
# dtype: int64

# %%
data_pre_model.head()
# Out:
#    item_date  quantity tons    customer  country status item type  \
# 0 2021-04-01      54.151139  30156308.0     28.0    Won         W
# 1 2021-04-01     768.024839  30202938.0     25.0    Won         W
# 2 2021-04-01     386.127949  30153963.0     30.0    Won        WI
# 3 2021-04-01     202.411065  30349574.0     32.0    Won         S
# 4 2021-04-01     785.526262  30211560.0     28.0    Won         W
#
#    application  thickness   width  product_ref delivery date  selling_price
# 0         10.0       2.00  1500.0   1670798778    2021-07-01         854.00
# 1         41.0       0.80  1210.0   1668701718    2021-04-01        1047.00
# 2         28.0       0.38   952.0       628377    2021-01-01         644.33
# 3         59.0       2.30  1317.0   1668701718    2021-01-01         768.00
# 4         10.0       4.00  2000.0       640665    2021-03-01         577.00

# %%
data_pre_model.describe()
# Out:
#                            item_date  quantity tons      customer  \
# count                         181672   1.816720e+05  1.816720e+05
# mean   2020-11-26 22:57:12.436478976   5.874937e+03  3.051221e+07
# min              2020-07-02 00:00:00   1.000000e-05  1.245800e+04
# 25%              2020-09-29 00:00:00   1.097160e+01  3.019688e+07
# 50%              2020-11-30 00:00:00   3.036500e+01  3.020524e+07
# 75%              2021-02-03 00:00:00   6.715941e+01  3.028042e+07
# max              2021-04-01 00:00:00   1.000000e+09  2.147484e+09
# std                              NaN   2.349081e+06  2.433382e+07
#
#              country    application      thickness          width  \
# count  181672.000000  181672.000000  181672.000000  181672.000000
# mean       44.890759      25.614492       2.564816    1295.286863
# min        25.000000       2.000000       0.180000       1.000000
# 25%        26.000000      10.000000       0.700000    1180.000000
# ...

# %% [markdown]
# EDA SKEW AND OUTLIERS HANDLING

# %%
#EDA Skew and Outliers Handling
data_pre_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 181672 entries, 0 to 181672
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   item_date      181672 non-null  datetime64[ns]
#  1   quantity tons  181672 non-null  float64
#  2   customer       181672 non-null  float64
#  3   country        181672 non-null  float64
#  4   status         181672 non-null  object
#  5   item type      181672 non-null  object
#  6   application    181672 non-null  float64
#  7   thickness      181672 non-null  float64
#  8   width          181672 non-null  float64
#  9   product_ref    181672 non-null  int64
#  10  delivery date  181672 non-null  datetime64[ns]
#  11  selling_price  181672 non-null  float64
# dtypes: datetime64[ns](2), float64(7), int64(1), object(2)
# memory usage: 18.0+ MB

# %%
data_pre_model['quantity tons'].skew()
# Out:
# 424.68964761973734

# %%
data_pre_model['application'].skew()
# Out:
# 0.7245562355387086

# %%
data_pre_model['country'].skew()
# Out:
# 0.7538292521838716

# %%
data_pre_model['customer'].skew()
# Out:
# 86.98506886298748

# %%
data_pre_model['product_ref'].skew()
# Out:
# 1.0152381001889226

# %%
data_pre_model['selling_price'].skew()
# Out:
# 301.3872586669224

# %%
data_pre_model['thickness'].skew()
# Out:
# 303.4467890875871

# %%
data_pre_model['width'].skew()
# Out:
# 0.3745941788011561

# %%
data_pre_model.status.unique()
# Out:
# array(['Won', 'Draft', 'To be approved', 'Lost', 'Not lost for AM',
#        'Wonderful', 'Revised', 'Offered', 'Offerable'], dtype=object)

# %%
data_pre_model.columns
# Out:
# Index(['item_date', 'quantity tons', 'customer', 'country', 'status',
#        'item type', 'application', 'thickness', 'width', 'product_ref',
#        'delivery date', 'selling_price'],
#       dtype='object')

# %%
data_pre_model["quantity_tons_log"] = np.log(data_pre_model['quantity tons'])
data_pre_model['selling_price_log'] = np.log(data_pre_model['selling_price'])
data_pre_model['thickness_log'] = np.log(data_pre_model['thickness'])
data_pre_model['country_log'] = np.log(data_pre_model['country'])
data_pre_model['application_log'] = np.log(data_pre_model['application'])
data_pre_model['width_log'] = np.log(data_pre_model['width'])

# %%
values1 = ["quantity tons",'selling_price','thickness',"country","application","width"]
values2 = ["quantity_tons_log",'selling_price_log','thickness_log',"country_log","application_log","width_log"]

# %%
data_pre_model.describe().T
# Out:
#                       count                           mean  \
# item_date            181672  2020-11-26 22:57:12.436478976
# quantity tons      181672.0                    5874.936598
# customer           181672.0                30512209.027968
# country            181672.0                      44.890759
# application        181672.0                      25.614492
# thickness          181672.0                       2.564816
# width              181672.0                    1295.286863
# product_ref        181672.0               473961322.857903
# delivery date        181672  2021-01-25 22:43:47.751111680
# selling_price      181672.0                    1918.082524
# quantity_tons_log  181672.0                         3.3921
# selling_price_log  181672.0                       6.625891
# thickness_log      181672.0                       0.480368
# country_log        181672.0                        3.67089
# application_log    181672.0                       2.992196
# ...

# %%
#creating visualisations by comparing the skew

import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import skew

class DataPlotter:
    def __init__(self, data):
        self.data = data

    def skews_plot(self, values1, values2):
        
        for v1, v2 in zip(values1, values2):
            plt.figure(figsize=(18, 6))
            
            # Boxplot before transformation
            plt.subplot(1, 3, 1)
            sns.boxplot(x=v1, data=self.data, color="rebeccapurple")
            plt.title(f'Boxplot - Before Transformation')

            # Histogram before transformation
            plt.subplot(1, 3, 2)
            sns.histplot(self.data[v1], kde=True, bins=30, color="aqua")
            plt.title(f'Histogram - Before Transformation\nSkewness: {skew(self.data[v1])}')

            # Violinplot before transformation
            plt.subplot(1, 3, 3)
            sns.violinplot(x=v1, data=self.data, color="saddlebrown")
            plt.title(f'Violinplot - Before Transformation')

            plt.tight_layout()
            plt.show()
            
            plt.figure(figsize=(18, 6))

            # Boxplot after transformation
            plt.subplot(1, 3, 1)
            sns.boxplot(x=v2, data=self.data, color="mediumvioletred")
            plt.title(f'Boxplot - After Transformation')

            # Histogram after transformation
            plt.subplot(1, 3, 2)
            sns.histplot(self.data[v2], kde=True, bins=30, color="royalblue")
            plt.title(f'Histogram - After Transformation\nSkewness: {skew(self.data[v2])}')

            # Violinplot after transformation
            plt.subplot(1, 3, 3)
            sns.violinplot(x=v2, data=self.data, color="navy")
            plt.title(f'Violinplot - After Transformation')

            plt.tight_layout()
            plt.show()

plotter = DataPlotter(data_pre_model)
plotter.skews_plot(values1, values2)
# Out:
# c:\Users\ADMIN\Desktop\raraj\.venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ADMIN\Desktop\raraj\.venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ADMIN\Desktop\raraj\.venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# FEATURE ENGINEERING

# %%
#Feature Engineering
data_pre_model.columns
# Out:
# Index(['item_date', 'quantity tons', 'customer', 'country', 'status',
#        'item type', 'application', 'thickness', 'width', 'product_ref',
#        'delivery date', 'selling_price', 'quantity_tons_log',
#        'selling_price_log', 'thickness_log', 'country_log', 'application_log',
#        'width_log'],
#       dtype='object')

# %%
data_pre_model['item_day'] = data_pre_model['item_date'].dt.day
data_pre_model['item_month'] = data_pre_model['item_date'].dt.month
data_pre_model['item_year'] = data_pre_model['item_date'].dt.year

# %%
#heatmap visualization of the correlation matrix

plt.figure(figsize=(10,8))
corrls=["quantity tons", "customer", "country", "application", "thickness", "selling_price"]
sns.heatmap(data_pre_model[corrls].corr(),annot=True,fmt='.3f',linewidths=2,cmap='BuPu')
plt.title('Correlation Matrix')
plt.show()

# %%
#visualisations for the correlations between features change after applying a log transformation.

plt.figure(figsize=(10,8))
skew_log=['selling_price_log','quantity_tons_log',"width_log","thickness_log","country_log","application_log"]
sns.heatmap(data_pre_model[skew_log].corr(),annot=True,fmt='.3f',linewidths=2,cmap='YlOrBr')
plt.title('Log Transformation Correlation Matrix')
plt.show()

# %%
#calculating and printing the upper and lower bounds for the thickness_log feature based on its mean and standard deviation

print("Highest allowed",data_pre_model['thickness_log'].mean() + 3*data_pre_model['thickness_log'].std())
print("Lowest allowed",data_pre_model['thickness_log'].mean() - 3*data_pre_model['thickness_log'].std())
# Out:
# Highest allowed 3.281680907816038
# Lowest allowed -2.320945275937669

# %% [markdown]
# OUTLIER HANDLING

# %%
# Outlier handling

#Finding the IQR
percentile25 = data_pre_model['selling_price'].quantile(0.25)
percentile75 = data_pre_model['selling_price'].quantile(0.75)
iqr=percentile75 - percentile25
print(iqr)
print(percentile25)
print(percentile75)

#Finding upper and lower limit
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print(f"upper bound of {upper_limit}")
print(f"lower bound of {lower_limit}")
# Out:
# 284.0
# 669.0
# 953.0
# upper bound of 1379.0
# lower bound of 243.0

# %%
# For all columns
def iqr_lower_bound(data_pre_model, col):
    Q1 = data_pre_model[col].quantile(0.25)
    Q3= data_pre_model[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - (1.5*IQR)
    return lower_bound
    
def iqr_upper_bound(data_pre_model, col):
    Q1 = data_pre_model[col].quantile(0.25)
    Q3= data_pre_model[col].quantile(0.75)
    IQR = Q3 - Q1
    upper_bound = Q3 + (1.5*IQR)
    return upper_bound

# %%
col_out = ["quantity_tons_log", 'selling_price_log','thickness_log','width','application_log']

# %%
{f"upper bound of {i}": iqr_upper_bound(data_pre_model,i) for i in col_out}
# Out:
# {'upper bound of quantity_tons_log': 6.9247077927406115,
#  'upper bound of selling_price_log': 7.390361168943161,
#  'upper bound of thickness_log': 3.281543137578373,
#  'upper bound of width': 1980.0,
#  'upper bound of application_log': 5.830052527269701}

# %%
{f"lower bound of {i}": iqr_lower_bound(data_pre_model,i) for i in col_out}
# Out:
# {'lower bound of quantity_tons_log': -0.32232880043819145,
#  'lower bound of selling_price_log': 5.9750377948392694,
#  'lower bound of thickness_log': -2.5396057928489957,
#  'lower bound of width': 700.0,
#  'lower bound of application_log': 0.18610463242865283}

# %%
df1=data_pre_model.copy()
df1.head(2)
# Out:
#    item_date  quantity tons    customer  country status item type  \
# 0 2021-04-01      54.151139  30156308.0     28.0    Won         W
# 1 2021-04-01     768.024839  30202938.0     25.0    Won         W
#
#    application  thickness   width  product_ref  ... selling_price  \
# 0         10.0        2.0  1500.0   1670798778  ...         854.0
# 1         41.0        0.8  1210.0   1668701718  ...        1047.0
#
#    quantity_tons_log  selling_price_log  thickness_log  country_log  \
# 0           3.991779           6.749931       0.693147     3.332205
# 1           6.643822           6.953684      -0.223144     3.218876
#
#    application_log  width_log  item_day  item_month  item_year
# 0         2.302585   7.313220         1           4       2021
# 1         3.713572   7.098376         1           4       2021
#
# [2 rows x 21 columns]

# %%
outlier_columns=['quantity_tons_log','selling_price_log', 'thickness_log', 'application_log']

# %%
#outlier_columns visualisation
import matplotlib.pyplot as plt
import seaborn as sns

def outlier_plot(df1, outlier_columns):
    for col in outlier_columns:
        plt.figure(figsize=(18, 6))
        
        # Boxplot
        plt.subplot(1, 3, 1)
        sns.boxplot(df1[col], color="palegoldenrod")
        plt.title('Boxplot')

        # Histogram
        plt.subplot(1, 3, 2)
        sns.histplot(df1[col], kde=True, bins=30, color="yellowgreen")
        plt.title('Histogram')

        # Violinplot
        plt.subplot(1, 3, 3)
        sns.violinplot(x=df1[col], color="crimson")
        plt.title('Violinplot')

        plt.tight_layout()
        plt.show()

outlier_plot(df1, outlier_columns)
# Out:
# c:\Users\ADMIN\Desktop\raraj\.venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ADMIN\Desktop\raraj\.venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ADMIN\Desktop\raraj\.venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df1.describe().T
# Out:
#                       count                           mean  \
# item_date            181672  2020-11-26 22:57:12.436478976
# quantity tons      181672.0                    5874.936598
# customer           181672.0                30512209.027968
# country            181672.0                      44.890759
# application        181672.0                      25.614492
# thickness          181672.0                       2.564816
# width              181672.0                    1295.286863
# product_ref        181672.0               473961322.857903
# delivery date        181672  2021-01-25 22:43:47.751111680
# selling_price      181672.0                    1918.082524
# quantity_tons_log  181672.0                         3.3921
# selling_price_log  181672.0                       6.625891
# thickness_log      181672.0                       0.480368
# country_log        181672.0                        3.67089
# application_log    181672.0                       2.992196
# ...

# %%
df1.columns
# Out:
# Index(['item_date', 'quantity tons', 'customer', 'country', 'status',
#        'item type', 'application', 'thickness', 'width', 'product_ref',
#        'delivery date', 'selling_price', 'quantity_tons_log',
#        'selling_price_log', 'thickness_log', 'country_log', 'application_log',
#        'width_log', 'item_day', 'item_month', 'item_year'],
#       dtype='object')

# %% [markdown]
# MACHINE LEARNING

# %% [markdown]
# #Regression Model

# %% [markdown]
# !pip install scikit-learn

# %%
#ordinal encoding on categorical features
from sklearn.preprocessing import OrdinalEncoder
OE = OrdinalEncoder()
df1['status_en'] = OE.fit_transform(df1[['status']])
df1['item_type_en'] = OE.fit_transform(df1[['item type']])

# %%
df1.head(2)
# Out:
#    item_date  quantity tons    customer  country status item type  \
# 0 2021-04-01      54.151139  30156308.0     28.0    Won         W
# 1 2021-04-01     768.024839  30202938.0     25.0    Won         W
#
#    application  thickness   width  product_ref  ... selling_price_log  \
# 0         10.0        2.0  1500.0   1670798778  ...          6.749931
# 1         41.0        0.8  1210.0   1668701718  ...          6.953684
#
#    thickness_log  country_log  application_log  width_log  item_day  \
# 0       0.693147     3.332205         2.302585   7.313220         1
# 1      -0.223144     3.218876         3.713572   7.098376         1
#
#    item_month  item_year  status_en  item_type_en
# 0           4       2021        7.0           5.0
# 1           4       2021        7.0           5.0
#
# [2 rows x 23 columns]

# %%
df1.columns
# Out:
# Index(['item_date', 'quantity tons', 'customer', 'country', 'status',
#        'item type', 'application', 'thickness', 'width', 'product_ref',
#        'delivery date', 'selling_price', 'quantity_tons_log',
#        'selling_price_log', 'thickness_log', 'country_log', 'application_log',
#        'width_log', 'item_day', 'item_month', 'item_year', 'status_en',
#        'item_type_en'],
#       dtype='object')

# %% [markdown]
# !pip install xgboost

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor, ExtraTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from xgboost import XGBRegressor

class RegressionModel:
    def __init__(self, df):
        self.df = df
        self.preprocess_data()
        self.split_data()
        self.initialize_models()
        
    def preprocess_data(self):
        self.x_reg = self.df[['quantity_tons_log','status_en', 'item_type_en', 'application', 'thickness_log', 'width', 'country', 'customer', 'product_ref']]
        self.y_reg = self.df['selling_price_log']
    
    def split_data(self):
        self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(self.x_reg, self.y_reg, test_size=0.3, random_state=5)
        print(f'Train shape: {self.X_train.shape}')
        print(f'Test shape: {self.X_test.shape}')
        print(f'Train labels shape: {self.y_train.shape}')
        print(f'Test labels shape: {self.y_test.shape}')
    
    def initialize_models(self):
        self.models = {
            'LinearRegression': LinearRegression(),
            'DecisionTreeRegressor': DecisionTreeRegressor(),
            'RandomForestRegressor': RandomForestRegressor(),
            'GradientBoostingRegressor': GradientBoostingRegressor(),
            'ExtraTreeRegressor': ExtraTreeRegressor(),
            'XGBRegressor': XGBRegressor()
        }
    
    def evaluate_model(self, model_name, model):
        model.fit(self.X_train, self.y_train)
        y_pred = model.predict(self.X_test)
        mse = mean_squared_error(self.y_test, y_pred)
        r2 = r2_score(self.y_test, y_pred)
        mae = mean_absolute_error(self.y_test, y_pred)
        
        return {
            'Model_Name': model_name,
            'Model': model,
            'Mean_Squared_Error': mse,
            'R_Squared': r2,
            'Mean_Absolute_Error': mae
        }
    
    def all_models(self):
        results = [self.evaluate_model(model_name, model) for model_name, model in self.models.items()]
        self.model_score_df = pd.DataFrame(results)
        return self.model_score_df.drop(columns=['Model'])
    
    def get_best_model(self, metric='R_Squared'):
        if self.model_score_df is None:
            raise ValueError("Model scores are not available. Please run all_models() first.")

        best_model_row = self.model_score_df.loc[self.model_score_df[metric].idxmax()]
        return best_model_row['Model']

model = RegressionModel(df1)
results = model.all_models()

print("\n**Evaluation Metrics for All Algorithms:**\n")
print(results.to_string(index=False))

best_model = model.get_best_model()
print("\n**Best Model Based on R_Squared:**\n")
print(results.loc[results['R_Squared'].idxmax()].to_string(index=False))
# Out:
# Train shape: (127170, 9)
# Test shape: (54502, 9)
# Train labels shape: (127170,)
# Test labels shape: (54502,)
#
# **Evaluation Metrics for All Algorithms:**
#
#                Model_Name  Mean_Squared_Error  R_Squared  Mean_Absolute_Error
#          LinearRegression            0.293504   0.086396             0.272681
#     DecisionTreeRegressor            0.037745   0.882509             0.126910
#     RandomForestRegressor            0.020734   0.935459             0.106185
# GradientBoostingRegressor            0.033408   0.896009             0.154205
#        ExtraTreeRegressor            0.041693   0.870219             0.131420
#              XGBRegressor            0.025051   0.922022             0.128321
#
# **Best Model Based on R_Squared:**
#
# RandomForestRegressor
#              0.020734
#              0.935459
#              0.106185

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor, ExtraTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from xgboost import XGBRegressor

class RegressionModel:
    def __init__(self, df):
        self.df = df
        self.preprocess_data()
        self.split_data()
        self.initialize_models()
        
    def preprocess_data(self):
        self.x_reg = self.df[['quantity_tons_log','status_en', 'item_type_en', 'application', 'thickness_log', 'width', 'country', 'customer', 'product_ref']]
        self.y_reg = self.df['selling_price_log']
    
    def split_data(self):
        self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(self.x_reg, self.y_reg, test_size=0.3, random_state=5)
        print(f'Train shape: {self.X_train.shape}')
        print(f'Test shape: {self.X_test.shape}')
        print(f'Train labels shape: {self.y_train.shape}')
        print(f'Test labels shape: {self.y_test.shape}')
    
    def initialize_models(self):
        self.models = {
            'LinearRegression': LinearRegression(),
            'DecisionTreeRegressor': DecisionTreeRegressor(),
            'RandomForestRegressor': RandomForestRegressor(),
            'GradientBoostingRegressor': GradientBoostingRegressor(),
            'ExtraTreeRegressor': ExtraTreeRegressor(),
            'XGBRegressor': XGBRegressor()
        }
    
    def evaluate_model(self, model_name, model):
        model.fit(self.X_train, self.y_train)
        y_pred = model.predict(self.X_test)
        mse = mean_squared_error(self.y_test, y_pred)
        r2 = r2_score(self.y_test, y_pred)
        mae = mean_absolute_error(self.y_test, y_pred)
        
        return {
            'Model_Name': model_name,
            'Model': model,
            'Mean_Squared_Error': mse,
            'R_Squared': r2,
            'Mean_Absolute_Error': mae
        }
    
    def all_models(self):
        results = [self.evaluate_model(model_name, model) for model_name, model in self.models.items()]
        self.model_score_df = pd.DataFrame(results)
        return self.model_score_df.drop(columns=['Model'])
    
    def get_best_model(self, metric='R_Squared'):
        if self.model_score_df is None:
            raise ValueError("Model scores are not available. Please run all_models() first.")

        best_model_row = self.model_score_df.loc[self.model_score_df[metric].idxmax()]
        return best_model_row['Model']

model = RegressionModel(df1)
results = model.all_models()

print("\n**Evaluation Metrics for All Algorithms:**\n")
print(results.to_string(index=False))

best_model = model.get_best_model()
print("\n**Best Model Based on R_Squared:**\n")
print(results.loc[results['R_Squared'].idxmax()].to_string(index=False))
# Out:
# Train shape: (127170, 9)
# Test shape: (54502, 9)
# Train labels shape: (127170,)
# Test labels shape: (54502,)
#
# **Evaluation Metrics for All Algorithms:**
#
#                Model_Name  Mean_Squared_Error  R_Squared  Mean_Absolute_Error
#          LinearRegression            0.293504   0.086396             0.272681
#     DecisionTreeRegressor            0.037510   0.883242             0.126297
#     RandomForestRegressor            0.020802   0.935250             0.106231
# GradientBoostingRegressor            0.033408   0.896009             0.154204
#        ExtraTreeRegressor            0.042685   0.867132             0.131348
#              XGBRegressor            0.025051   0.922022             0.128321
#
# **Best Model Based on R_Squared:**
#
# RandomForestRegressor
#              0.020802
#               0.93525
#              0.106231

# %%
#the code for  best combination of hyperparameters based on cross-validation performance on the training data
from sklearn.model_selection import GridSearchCV
x = df1[['quantity_tons_log','status_en','item_type_en','application', 'thickness_log', 'width', 'country', 'customer', 'product_ref']]
y = df1['selling_price_log']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Parameters for GridSearchCV
parameters = {
    "max_depth": [20],
    "min_samples_split": [2],
    "min_samples_leaf": [1],
    "max_features": [None]
}

# Define the GridSearchCV with RandomForestCRegressor
gridsearch = GridSearchCV(estimator=RandomForestRegressor(), param_grid=parameters, cv=5, n_jobs=-1)
gridsearch.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [20], 'max_features': [None],
#                          'min_samples_leaf': [1], 'min_samples_split': [2]})

# %%
gridsearch.best_params_
# Out:
# {'max_depth': 20,
#  'max_features': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2}

# %%
x.head(2)
# Out:
#    quantity_tons_log  status_en  item_type_en  application  thickness_log  \
# 0           3.991779        7.0           5.0         10.0       0.693147
# 1           6.643822        7.0           5.0         41.0      -0.223144
#
#     width  country    customer  product_ref
# 0  1500.0     28.0  30156308.0   1670798778
# 1  1210.0     25.0  30202938.0   1668701718

# %%
# r2_train and r2_test values measure the Random Forest Regression model that fits the training data and generalizes to unseen data


x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=42)
model = RandomForestRegressor(max_depth=20,max_features=None,min_samples_leaf=1,min_samples_split=2).fit(x_train,y_train)

y_pred_train = model.predict(x_train) # Makes predictions on the training and testing sets
y_pred_test = model.predict(x_test)

r2_train = r2_score(y_train, y_pred_train) #coefficient of determination for both training and testing sets.
r2_test = r2_score(y_test, y_pred_test)
r2_train, r2_test
# Out:
# (0.9706160981058295, 0.9380671929485136)

# %%
#predicting the PRICE OF selling of new products  a trained Random Forest Regression model by its features
new_quantity_tons_log = np.log(40)
status_en = 5.0
item_type_en = 4.0
application = 20.0
new_thickness_log = np.log(250)
new_width = 28
country = 25.0
new_customer = 30202938
new_product_ref = 1670798778

# Define feature names
feature_names = ['quantity_tons_log','status_en', 'item_type_en', 'application', 
                'thickness_log', 'width', 'country', 'customer', 'product_ref']
new_sample = np.array([[new_quantity_tons_log,status_en,item_type_en,application,
                        new_thickness_log, new_width, country, new_customer, new_product_ref]])

new_pred = model.predict(new_sample)
print("Selling Price:", np.exp(new_pred)[0])
# Out:
# Selling Price: 691.3829191941944
# c:\Users\ADMIN\Desktop\raraj\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
new_pred #storing the predicted log seeking price value
# Out:
# array([6.53869382])

# %%
# # Saving the model(preserving)

import pickle
with open('RegressionModel.pkl','wb') as file:
    pickle.dump(model, file)

# %%
#loading

with open("RegressionModel.pkl","rb") as r1:
    regg_model=pickle.load(r1)

# %%
#these features as given in the input to machine learning to predict target variable 


new_quantity_tons_log = np.log(40)   #nat_log of quantity products
status_en = 5.0        #categorical feature represents of status of product
item_type_en = 4.0    # cat fe type of product
application = 20.0   # cat fe of app of product
new_thickness_log = np.log(250) #nat_log of new thickness
new_width = 28     #width of the product
country = 25.0    # country of origin product
new_customer = 30202938  #numerical feature representing the customer ID
new_product_ref = 1670798778  # numerical feature representing the product reference ID

# %%
#printing the predicted price in both log and actual value formats.


user_data1 = np.array([[new_quantity_tons_log,status_en,item_type_en,application,
                        new_thickness_log, new_width, country, new_customer, new_product_ref]])
y_pred_user1 = regg_model.predict(user_data1)
print("Predicted selling price with Log: ",y_pred_user1[0])
print("Predicted selling price without Log: ",np.exp(y_pred_user1[0]))
# Out:
# c:\Users\ADMIN\Desktop\raraj\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Predicted selling price with Log:  6.538693822516745
# Predicted selling price without Log:  691.3829191941944

# %% [markdown]
# CLASSIFICATION MODEL

# %%
#filtering
df2 = df1[df1['status'].isin(['Won', 'Lost'])]
df2.head(2)
# Out:
#    item_date  quantity tons    customer  country status item type  \
# 0 2021-04-01      54.151139  30156308.0     28.0    Won         W
# 1 2021-04-01     768.024839  30202938.0     25.0    Won         W
#
#    application  thickness   width  product_ref  ... selling_price_log  \
# 0         10.0        2.0  1500.0   1670798778  ...          6.749931
# 1         41.0        0.8  1210.0   1668701718  ...          6.953684
#
#    thickness_log  country_log  application_log  width_log  item_day  \
# 0       0.693147     3.332205         2.302585   7.313220         1
# 1      -0.223144     3.218876         3.713572   7.098376         1
#
#    item_month  item_year  status_en  item_type_en
# 0           4       2021        7.0           5.0
# 1           4       2021        7.0           5.0
#
# [2 rows x 23 columns]

# %%
df2["status_en"] = df2['status'].map({"Won":1, "Lost":0})
df2.columns
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_7880\4093412051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["status_en"] = df2['status'].map({"Won":1, "Lost":0})
# Index(['item_date', 'quantity tons', 'customer', 'country', 'status',
#        'item type', 'application', 'thickness', 'width', 'product_ref',
#        'delivery date', 'selling_price', 'quantity_tons_log',
#        'selling_price_log', 'thickness_log', 'country_log', 'application_log',
#        'width_log', 'item_day', 'item_month', 'item_year', 'status_en',
#        'item_type_en'],
#       dtype='object')

# %%
df3=df2[['quantity_tons_log','selling_price_log','application','thickness_log','width','country','customer','product_ref','status_en']]
df3.head(2)
# Out:
#    quantity_tons_log  selling_price_log  application  thickness_log   width  \
# 0           3.991779           6.749931         10.0       0.693147  1500.0
# 1           6.643822           6.953684         41.0      -0.223144  1210.0
#
#    country    customer  product_ref  status_en
# 0     28.0  30156308.0   1670798778          1
# 1     25.0  30202938.0   1668701718          1

# %%
x_class=df3.drop(['status_en'],axis=1)
y_class=df3['status_en']

# %%
# !pip install imblearn
# Out:
# ...
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\ADMIN\Desktop\raraj\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\ADMIN\Desktop\raraj\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\ADMIN\Desktop\raraj\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\ADMIN\Desktop\raraj\.venv\Lib\site-packages)
# ...

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_sm, y_sm = sm.fit_resample(x_class,y_class)
ax = y_sm.value_counts().plot.pie(autopct='%.2f')
_ = ax.set_title("Over-sampling using SMOTE")

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_sm, y_sm, test_size = 0.3, random_state = 5)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (162415, 8)
# (69607, 8)
# (162415,)
# (69607,)

# %%
#import classifier algorithms.
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import confusion_matrix,accuracy_score, classification_report

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)

y_pred_train = knn.predict(X_train)
y_pred = knn.predict(X_test)

accuracy_train = accuracy_score(y_train, y_pred_train)
accuracy_test = accuracy_score(y_test,y_pred)
print("Accuracy score for Train and Test")
print("------------------------------------")
print("Accuracy_Train: ",accuracy_train )
print("Accuracy_Test: ",accuracy_test)
print(" ")
result = confusion_matrix(y_test, y_pred)
print("------------------------------------")
print("Confusion Matrix:")
print(result)
result1 = classification_report(y_test, y_pred)
print("------------------------------------")
print("Classification Report:")
print(result1)
# Out:
# Accuracy score for Train and Test
# ------------------------------------
# Accuracy_Train:  0.9331465689745405
# Accuracy_Test:  0.8981711609464565
#
# ------------------------------------
# Confusion Matrix:
# [[32574  2433]
#  [ 4655 29945]]
# ------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90     35007
#            1       0.92      0.87      0.89     34600
#
#     accuracy                           0.90     69607
#    macro avg       0.90      0.90      0.90     69607
# weighted avg       0.90      0.90      0.90     69607

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

y_pred_train = rfc.predict(X_train)
y_pred = rfc.predict(X_test)

accuracy_train = accuracy_score(y_train, y_pred_train)
accuracy_test = accuracy_score(y_test,y_pred)
print("Accuracy score for Train and Test")
print("------------------------------------")
print("Accuracy_Train: ",accuracy_train )
print("Accuracy_Test: ",accuracy_test)

result = confusion_matrix(y_test, y_pred)
print("--------------------------------")
print("Confusion Matrix:")
print(result)
result1 = classification_report(y_test, y_pred)
print("--------------------------------")
print("Classification Report:")
print(result1)
# Out:
# Accuracy score for Train and Test
# ------------------------------------
# Accuracy_Train:  0.9999938429332266
# Accuracy_Test:  0.9498469981467381
# --------------------------------
# Confusion Matrix:
# [[33761  1246]
#  [ 2245 32355]]
# --------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95     35007
#            1       0.96      0.94      0.95     34600
#
#     accuracy                           0.95     69607
#    macro avg       0.95      0.95      0.95     69607
# weighted avg       0.95      0.95      0.95     69607

# %%
gbc = GradientBoostingClassifier()
gbc.fit(X_train, y_train)

y_pred_train = gbc.predict(X_train)
y_pred = gbc.predict(X_test)

accuracy_train = accuracy_score(y_train, y_pred_train)
accuracy_test = accuracy_score(y_test,y_pred)
print("Accuracy score for Train and Test")
print("------------------------------------")
print("Accuracy_Train: ",accuracy_train )
print("Accuracy_Test: ",accuracy_test)

result = confusion_matrix(y_test, y_pred)
print("------------------------------------")
print("Confusion Matrix:")
print(result)
result1 = classification_report(y_test, y_pred)
print("------------------------------------")
print("Classification Report:")
print(result1)
# Out:
# Accuracy score for Train and Test
# ------------------------------------
# Accuracy_Train:  0.7695471477388173
# Accuracy_Test:  0.7672647865875558
# ------------------------------------
# Confusion Matrix:
# [[28672  6335]
#  [ 9865 24735]]
# ------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.82      0.78     35007
#            1       0.80      0.71      0.75     34600
#
#     accuracy                           0.77     69607
#    macro avg       0.77      0.77      0.77     69607
# weighted avg       0.77      0.77      0.77     69607

# %%
from sklearn.model_selection import GridSearchCV
x_train, x_test, y_train, y_test = train_test_split(X_sm, y_sm, test_size=0.2, random_state=42)

# Parameters for GridSearchCV
parameters = {
    "max_depth": [20],
    "min_samples_split": [2],
    "min_samples_leaf": [1],
    "max_features": [None]
}

# Define the GridSearchCV with RandomForestClassifier
gridsearch = GridSearchCV(estimator=ExtraTreesClassifier(), param_grid=parameters, cv=5, n_jobs=-1)
gridsearch.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [20], 'max_features': [None],
#                          'min_samples_leaf': [1], 'min_samples_split': [2]})

# %%
gridsearch.best_params_
# Out:
# {'max_depth': 20,
#  'max_features': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2}

# %%
x_train,x_test,y_train,y_test = train_test_split(X_sm,y_sm, test_size=0.2, random_state=42)

models = ExtraTreesClassifier(max_depth=20,max_features=None,min_samples_leaf=1,min_samples_split=2).fit(x_train,y_train)

y_pred_train = models.predict(x_train)
y_pred_test = models.predict(x_test)

# checking the accuracy score for train and test
accuracy_train = accuracy_score(y_train,y_pred_train)
accuracy_test = accuracy_score(y_test,y_pred_test)

print("Accuracy score for Train and Test")
print("------------------------------------")
print("Accuracy_Train: ",accuracy_train )
print("Accuracy_Test: ",accuracy_test)

# confusion matrics and the classification report for test
print("Confusion_Matrix for Test")
print("---------------------------")
print(confusion_matrix(y_true=y_test,y_pred=y_pred_test))
print(" ")
print("Classification Report for Test")
print("--------------------------------")
print(classification_report(y_true=y_test,y_pred=y_pred_test))
# Out:
# Accuracy score for Train and Test
# ------------------------------------
# Accuracy_Train:  0.9689198726409758
# Accuracy_Test:  0.9409330891067773
# Confusion_Matrix for Test
# ---------------------------
# [[22651   665]
#  [ 2076 21013]]
#
# Classification Report for Test
# --------------------------------
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94     23316
#            1       0.97      0.91      0.94     23089
#
#     accuracy                           0.94     46405
#    macro avg       0.94      0.94      0.94     46405
# weighted avg       0.94      0.94      0.94     46405

# %%
X_sm
# Out:
#         quantity_tons_log  selling_price_log  application  thickness_log  \
# 0                3.991779           6.749931         10.0       0.693147
# 1                6.643822           6.953684         41.0      -0.223144
# 2                5.956169           6.468211         28.0      -0.967584
# 3                5.310301           6.643790         59.0       0.832909
# 4                6.666354           6.357842         10.0       1.386294
# ...                   ...                ...          ...            ...
# 232017           5.472540           6.710403         10.0       0.761632
# 232018           2.287942           6.614004         15.0       2.079442
# 232019           3.979693           6.531328         10.0       0.718270
# 232020           5.048801           6.917065         10.0       1.057623
# 232021           4.828486           6.463420         15.0       0.010972
#
#               width  country    customer  product_ref
# ...

# %%
new_quantity_tons_log = np.log(90)
selling_price_log = np.log(40)
application = 58
new_thickness_log = np.log(600)
new_width = 1800.0
country = 85
new_customer = 30201223
new_product_ref = 1671863738

# Create the new sample as a numpy array
new_sample = np.array([[new_quantity_tons_log, selling_price_log, application,
                        new_thickness_log, new_width, country, new_customer, new_product_ref]])

# Make predictions using the trained RandomForestRegressor model
new_pred = models.predict(new_sample)

if new_pred==1:
    print('The status is: Won')
else:
    print('The status is: Lost')
# Out:
# c:\Users\ADMIN\Desktop\raraj\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but ExtraTreesClassifier was fitted with feature names
#   warnings.warn(
# The status is: Won

# %%
# Saving the model
import pickle
with open('Classification.pkl', 'wb') as file:
    pickle.dump(rfc, file)

# %%
# import pickle
with open("Classification.pkl","rb") as f1:
    class_model = pickle.load(f1)
    
filtered_df = data_pre_model[data_pre_model['status'] == 'Lost']
filtered_df.tail(5)
# Out:
#         item_date  quantity tons    customer  country status item type  \
# 181527 2020-07-02      63.859521  30161559.0     30.0   Lost         S
# 181529 2020-07-02      56.028562  30161559.0     30.0   Lost         S
# 181531 2020-07-02     206.224110  30161559.0     30.0   Lost         S
# 181533 2020-07-02     102.993849  30198408.0     25.0   Lost         S
# 181535 2020-07-02     106.072262  30198408.0     25.0   Lost         S
#
#         application  thickness   width  product_ref  ... selling_price  \
# 181527         10.0       5.85  1525.0       640665  ...         457.0
# 181529         10.0       7.85  1500.0       640665  ...         458.0
# 181531         10.0       3.85  1830.0       640665  ...         460.0
# 181533         10.0       1.40  1150.0   1668701718  ...         725.0
# 181535         10.0       1.40  1146.0   1668701718  ...         727.0
#
#         quantity_tons_log  selling_price_log  thickness_log  country_log  \
# ...

# %%
new_quantity_tons_log = np.log(63)
selling_price_log = np.log(450)
application = 10
new_thickness_log = np.log(5.85)
new_width = 1525
country = 30
new_customer = 30161559
new_product_ref = 640665

# Create the new sample as a numpy array
new_sample = np.array([[new_quantity_tons_log, selling_price_log, application,
                        new_thickness_log, new_width, country, new_customer, new_product_ref]])

# Make predictions using the trained RandomForestRegressor model
new_pred = class_model.predict(new_sample)

if new_pred[0]==1:
    print('The status is: Won')
else:
    print('The status is: Lost')
